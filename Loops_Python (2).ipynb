# %% [markdown]
# ### CONTROL FLOW

# %%
def dave_check(user_name):
  if user_name == "Dave":
    return "Get off my computer Dave!"
  if user_name=="angela_catlady_87":
    return  "I know it is you Dave! Go away!"


  
# Enter a user name here, make sure to make it a string
user_name = "Dave"

print(dave_check(user_name))

#Relational Operator
def greater_than(x, y):
  if x > y:
    return x
  if y > x:
    return y
  if x == y:
    return "These numbers are the same"

print(greater_than(5,6))

#Boolean Operators
def graduation_reqs(gpa,credits):
  if credits >= 120 and gpa>=2.0:
    return "You meet the requirements to graduate!"

print(graduation_reqs(3.0,140))

def graduation_mailer(gpa, credits):
  if (gpa >= 2.0) or (credits >= 120):
    return True

print(graduation_mailer (3.0, 110))

#If Else
def graduation_reqs(gpa, credits):
  if (gpa >= 2.0) and (credits >= 120):
    return "You meet the requirements to graduate!"
  if (gpa >= 2.0) and not (credits >= 120):
    return "You do not have enough credits to graduate."
  if not (gpa >= 2.0) and (credits >= 120):
    return "Your GPA is not high enough to graduate."
  else:
    return "You do not meet the GPA or the credit requirement for graduation."

#Else If
def thank_you(donation):
  if donation >= 1000:
    print("Thank you for your donation! You have achieved platinum donation status!")
  elif donation >= 500: 
    print("Thank you for your donation! You have achieved gold donation status!")
  elif donation >= 100:
    print("Thank you for your donation! You have achieved silver donation status!")
  else:
    print("Thank you for your donation! You have achieved bronze donation status!")
# Out:
# Get off my computer Dave!
# 6
# You meet the requirements to graduate!
# True

# %% [markdown]
# ### LISTS IN PYTHON

# %%
sam_height =['Sam', 67]
print(sam_height)

ages=[['Aaron', 15], ['Dhruti', 16]]
print(ages)

empty_list = []

#append list
empty_list = []
empty_list.append(1)

# adding multiple elements
sam_height =['Sam', 67]
rohan_height=sam_height+['Rohan', 55]
print(rohan_height)

#Range
list1 = range(9)
print(list(list1))

#range II
list2=range(0,40,5)
print(list(list2))
# Out:
# ['Sam', 67]
# [['Aaron', 15], ['Dhruti', 16]]
# ['Sam', 67, 'Rohan', 55]
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# [0, 5, 10, 15, 20, 25, 30, 35]

# %% [markdown]
# # FOR LOOP

# %%
sport_games = ['football', 'football - American', 'hockey', 'baseball', 'cricket']


for games in sport_games: #for <temporary variable> in <list variable>:<action>
  print(games)
# Out:
# football
# football - American
# hockey
# baseball
# cricket

# %%
#Using Range in Loops. This will help us print a string multiple times
promise = "I will not chew gum in class"

for i in range(5):
  print(promise)
# Out:
# I will not chew gum in class
# I will not chew gum in class
# I will not chew gum in class
# I will not chew gum in class
# I will not chew gum in class

# %%
#Break in For Loop
dog_breeds_available_for_adoption = ['french_bulldog', 'dalmatian', 'shihtzu', 'poodle', 'collie']
dog_breed_I_want = 'dalmatian'
for dogs_available in dog_breeds_available_for_adoption:
    print(dogs_available)
    if dogs_available== dog_breed_I_want:
        print("They have the dog I want!")
        break
print("I have found my Dog Breed")
# Out:
# french_bulldog
# dalmatian
# They have the dog I want!
# I have found my Dog Breed

# %%
#Continue in For Loop
